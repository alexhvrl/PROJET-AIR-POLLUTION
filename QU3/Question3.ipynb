# %%
import pandas as pd

data = pd.read_csv('O3.csv')

data

O3_MAG = data['Magadino-Cadenazzo'].tolist()
O3_CHA = data['Chaumont'].tolist()
# Out:
#      Date/heure  Magadino-Cadenazzo  Chaumont
# 0    01.01.2024                57.4      75.9
# 1    02.01.2024                29.4      87.8
# 2    03.01.2024                40.4      87.8
# 3    04.01.2024                50.6      84.9
# 4    05.01.2024                42.0      80.7
# ..          ...                 ...       ...
# 361  27.12.2024                38.5      91.7
# 362  28.12.2024                37.9      88.8
# 363  29.12.2024                41.6      96.1
# 364  30.12.2024                30.1      97.5
# 365  31.12.2024                43.3      96.1
#
# [366 rows x 3 columns]

# %%
# Out:
# [57.4,
#  29.4,
#  40.4,
#  50.6,
#  42.0,
#  67.1,
#  70.7,
#  49.4,
#  47.8,
#  46.0,
#  43.3,
#  48.5,
#  56.9,
#  40.0,
#  64.7,
#  69.4,
#  37.0,
#  39.6,
#  84.9,
#  64.4,
#  61.4,
#  37.6,
#  85.9,
#  35.8,
#  50.0,
#  42.0,
#  79.3,
#  64.7,
#  56.8,
#  51.1,
#  39.8,
#  44.2,
#  57.3,
#  57.4,
#  70.7,
#  63.2,
#  57.6,
#  64.7,
#  54.9,
#  46.5,
#  61.9,
#  53.1,
#  50.4,
#  79.6,
#  75.7,
#  57.4,
#  50.4,
#  69.1,
#  64.1,
#  81.1,
#  94.3,
#  81.5,
#  54.1,
#  70.9,
#  64.2,
#  70.7,
#  66.3,
#  41.5,
#  52.1,
#  36.5,
#  54.5,
#  69.3,
#  79.5,
#  83.3,
#  72.2,
#  81.5,
#  74.2,
#  58.3,
#  72.8,
#  77.4,
#  89.0,
#  98.7,
#  92.8,
#  109.1,
#  98.7,
#  93.9,
#  84.2,
#  91.1,
#  92.5,
#  95.2,
#  101.6,
#  118.9,
#  112.1,
#  98.0,
#  96.5,
#  85.8,
#  66.6,
#  68.8,
#  62.5,
#  78.1,
#  74.6,
#  105.8,
#  97.5,
#  79.8,
#  100.1,
#  101.0,
#  106.0,
#  81.2,
#  124.9,
#  99.3,
#  89.5,
#  104.7,
#  119.5,
#  133.9,
#  128.3,
#  125.4,
#  112.6,
#  100.7,
#  97.2,
# ...
